# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome(executable_path = r'C:\Users\ajsre\.wdm\drivers\chromedriver\win32\85.0.4183.87\chromedriver.exe')
driver
driver.get('https://www.instagram.com/?hl=en')
driver.implicitly_wait(10)

# %% [markdown]
# importing libraries and passing the url of instagram

# %% [markdown]
# Question 1 part 1:

# %% [markdown]
# loging in :

# %%
name=driver.find_element_by_name('username')
name.send_keys('sample_username')
#seraching username textbox and sending the username

# %%
password=driver.find_element_by_name('password')
password.send_keys('sample_password')
#seraching username textbox and sending the username

# %%
enter=driver.find_elements_by_class_name('Igw0E')
enter[2].click()
#pressing enter

# %% [markdown]
# Question 2 Part 1:

# %%
search=driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
search.get_attribute('outerHTML')
search.send_keys('food')
#Searchin food

# %%
food=driver.find_elements_by_class_name('_2_M76')
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)
for i in food:
    nme=i.get_attribute('innerHTML')
    if '#' in nme:
        continue
    print(remove_html_tags(nme))
#getting a list of all tyhe handles that come after writing food 
#and removing the ones having # in it using remove_html_tags function
# Out:
# foodtalkindiaVerifiedFood Talk
# yourfoodlabVerifiedYour Food Lab
# foodfoodtvFoodFood - It's Sizzling
# meghnasfoodmagicVerifiedMeghna’s Food Magic
# foodnetworkVerifiedFood Network
# dilsefoodieVerifiedKaran Dua
# foodFood
# hmm_nikhilVerifiedNikhil Chawla | Delhi Food
# foodgodVerifiedFoodgod®️
# delhifoodguideDelhi Food Guide
# love_foodLove Food
# munchbeforecrunchFood | Riddhi shah
# foodnetworkkitchenVerifiedFood Network Kitchen
# buzzfeedfoodVerifiedBuzzFeed Food
# food52VerifiedFood52
# foodbabynyVerifiedFood Baby
# fooddotcomVerifiedFood.com
# the_food_corner_officialFOOD CORNER
# romancingthefoodKavita Ganguly
# food_lunaticDimple Arora
# foodofchennaiFood of Chennai | Food Blogger
# the_foodiediariesAyushi | The Foodie Diaries™
# foodbossindiaNeeda Khan⚡️
# food_belly11Dilpreet A.k.a Nupur Kochhar
# food_juncKarnika Chandna
# foodiesforalwaysFood Bloggers
# abhisheksinghdavid__foodloveAbhisheksinghdavid (Food Love)
# food.darzeeVerifiedFood Darzee
# ...

# %%
search.clear()
#clear search

# %% [markdown]
# Question3 part 1:

# %%
search.send_keys('So Delhi')
driver.implicitly_wait(4)
#searching So Delhi

# %%
Sodelhi=driver.find_element_by_class_name('z556c')
Sodelhi.click()
# clicking So delhii's Handle

# %% [markdown]
# Question 4:

# %%
follow=driver.find_element_by_class_name('_5f5mN')

if follow.get_attribute('innerHTML')=='Follow':
    #finding follow button and clicking it
     follow.click()
else:    
    print('already followed')
driver.implicitly_wait(4)    
#following the handle , if already followed , then printing already followed

# %%
from selenium.common.exceptions import NoSuchElementException
try:
    unfollow=driver.find_element_by_css_selector('#react-root > section > main > div > header > section > div.nZSzR > div.Igw0E.IwRSH.eGOV_.ybXk5._4EzTm > div > div:nth-child(2) > div > span > span.vBF20._1OSdk > button > div > span')
    if unfollow.get_attribute('aria-label')=='Following':
            unfollow.click()
             #finding unfollow button and clicking it
            button=driver.find_element_by_xpath('/html/body/div[4]/div/div/div/div[3]/button[1]')
            button.click()
except NoSuchElementException:
    #using no  element exception here if we are not able to find unfollow button, then print  already unfollowed
           print('already unfollowed')
#UNnollowing the handle , if already followed , then printing already Unfollowed

# %% [markdown]
# Question 5 Part 1:

# %%
search=driver.find_element_by_css_selector('#react-root > section > nav > div._8MQSO.Cx7Bp > div > div > div.LWmhU._0aCwM > input')

search.send_keys('dilsefoodie')
#searching search button and searching dilsefoodie

# %%
dilsefoodie=driver.find_element_by_class_name('z556c')
dilsefoodie.click()
driver.implicitly_wait(4)
#clicking on Dilsefoodie's handle

# %%
import time
#importing time
post=driver.find_element_by_class_name('_9AhH0')
# finding first post and 
post.click()
#clicking it
driver.implicitly_wait(3)
for i in range(0,30):
    #traversing 30 posts
    like=driver.find_element_by_class_name('fr66n')
    #finding like button
    like.get_attribute('innerHTML')
    k=like.find_element_by_tag_name('svg')  
    if k.get_attribute('aria-label')=='Unlike':
             print('post',i+1,'already liked')
    #if post is already liked then printing already liked        
             
    else:           
        like.click()            
    #else liking it 
  
    next_pg=driver.find_element_by_class_name('_65Bje')
    next_pg.click()
    #finding the next page button and clicking it.
    time.sleep(1)

close=driver.find_element_by_xpath('/html/body/div[4]/div[3]/button')
close.click()  
# closing on last post

# %% [markdown]
# Question 5 Part 2:

# %%
post=driver.find_element_by_class_name('_9AhH0')
# finding first post and 
post.click()
#clicking it
driver.implicitly_wait(3)

for i in range(0,30):
    #traversing 30 posts
    unlike=driver.find_element_by_class_name('fr66n')
    unlike.get_attribute('innerHTML')
    #finding Unlike button
    k=unlike.find_element_by_tag_name('svg')  
    if k.get_attribute('aria-label')=='Like':
             print('post',i+1,'already Unliked')
     #if post is already unliked then printing already unliked          
    else:           
        unlike.click()            
    
    #else unliking it     
    next_pg=driver.find_element_by_class_name('_65Bje')
    next_pg.click()
    #finding the next page button and clicking it.
    time.sleep(3)
close=driver.find_element_by_xpath('/html/body/div[4]/div[3]/button/div')
close.click()  
# closing on last post

# %% [markdown]
# Question 6 Part 1 :

# %%
search=driver.find_element_by_class_name('XTCLo')
search.send_keys('foodtalkindia')
#searching the handle of food talkindia

# %%
foodtalkIndia=driver.find_element_by_class_name('z556c')
foodtalkIndia.click()
#clicking it

# %%
followers_button=driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a')
followers_button.click()
driver.implicitly_wait(2)
#finding follower button and clicking it

# %%
count=0
lst_of_foodtalk=[]
#defining a LIST to append followers of food talk india
while count<500:
    #getting the first 500 followers of foodtalkindia
        lst=driver.find_elements_by_class_name('d7ByH')
        #finding the list followers by finding the class
        for i in range(len(lst)):
            if count < 500:
                print(str(count+1)+'.', remove_html_tags(lst[i].get_attribute('innerHTML')))
                lst_of_foodtalk.append( remove_html_tags(lst[i].get_attribute('innerHTML')))
                #appending the list by foodtalk followers
                count+=1  
        
        
        scr1 = driver.find_element_by_class_name('isgrP')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)
        #scrolling to get the new list of followers until required number of followers is reached

        time.sleep(4)
# Out:
# 1. momsbakezone
# 2. simply_unique_1
# 3. aryanirfan94
# 4. kitchenkingkhan
# 5. _paramsharma._
# 6. neerja_recipes
# 7. zaibali123fp
# 8. shadab__khan8
# 9. oasiaan
# 10. bhoookhlagihai
# 11. shantanu1000
# 12. shalimarplastopack
# 13. tulsh_iparmar
# 14. tree_arana
# 15. muktar7611
# 16. maazkhan7789
# 17. 1927___fatima
# 18. jennieroseq
# 19. shades_of_ghaziabad
# 20. craving_palate
# 21. shrikantchavan.24
# 22. bittu_rawat824
# 23. zhangfanshu6
# 24. tastyytasty
# 25. momsbakezone
# 26. simply_unique_1
# 27. aryanirfan94
# 28. kitchenkingkhan
# 29. _paramsharma._
# 30. neerja_recipes
# 31. zaibali123fp
# 32. shadab__khan8
# 33. oasiaan
# 34. bhoookhlagihai
# 35. shantanu1000
# 36. shalimarplastopack
# 37. tulsh_iparmar
# 38. tree_arana
# 39. muktar7611
# 40. maazkhan7789
# 41. 1927___fatima
# 42. jennieroseq
# 43. shades_of_ghaziabad
# 44. craving_palate
# 45. shrikantchavan.24
# 46. bittu_rawat824
# 47. zhangfanshu6
# 48. tastyytasty
# 49. roshani_1718
# 50. dnavoneel
# ...

# %%
close=driver.find_element_by_css_selector('body > div.RnEpo.Yx5HN > div > div > div:nth-child(1) > div > div:nth-child(3) > button > div')
close.click()
#closing the list

# %%
search=driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
search.send_keys('SoDelhi')
driver.implicitly_wait(2)
#finding search button and searching So delhi in it

# %%
SoDelhi=driver.find_element_by_class_name('z556c')
SoDelhi.click()
# clicking on So Delhi's Handle

# %%
followers_button=driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a')
followers_button.click()
driver.implicitly_wait(2)

# %%
count=0
while count<500:
        lst=driver.find_elements_by_class_name('d7ByH')
        for i in range(len(lst)):
            if count < 500:
                print(str(count+1)+'.', remove_html_tags(lst[i].get_attribute('innerHTML')))
                count+=1  
        # print(len(lst))
        
        scr1 = driver.find_element_by_class_name('isgrP')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)

        time.sleep(4)
#findinhg so delhi's first 500 followers
# Out:
# 1. poojaaggarwal89
# 2. the.foood.xplorer
# 3. 23maestro
# 4. bhawana.tiwari
# 5. casadedelhi
# 6. deep_guha_life
# 7. foods_fun_life
# 8. summs_m
# 9. ansh._06
# 10. tanishamittal382001
# 11. artynifty
# 12. surajshinde9115
# 13. trickyxanny
# 14. a_serene_chaos
# 15. adi.anjaani
# 16. thenameisyudhisthir
# 17. manleen.kaur12
# 18. prerna_tariyal
# 19. rashika_gera
# 20. themoodygal123
# 21. sharath0104
# 22. vikramgour82
# 23. aksh_for_u_
# 24. aashi_rawat29
# 25. poojaaggarwal89
# 26. the.foood.xplorer
# 27. 23maestro
# 28. bhawana.tiwari
# 29. casadedelhi
# 30. deep_guha_life
# 31. foods_fun_life
# 32. summs_m
# 33. ansh._06
# 34. tanishamittal382001
# 35. artynifty
# 36. surajshinde9115
# 37. trickyxanny
# 38. a_serene_chaos
# 39. adi.anjaani
# 40. thenameisyudhisthir
# 41. manleen.kaur12
# 42. prerna_tariyal
# 43. rashika_gera
# 44. themoodygal123
# 45. sharath0104
# 46. vikramgour82
# 47. aksh_for_u_
# 48. aashi_rawat29
# 49. poojaaggarwal89
# 50. the.foood.xplorer
# ...

# %%
close=driver.find_element_by_css_selector('body > div.RnEpo.Yx5HN > div > div > div:nth-child(1) > div > div:nth-child(3) > button > div')
close.click()
#closing it

# %% [markdown]
# Question 6 Part 2:

# %%
profile=driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/div[5]/span/img')
profile.click()
driver.implicitly_wait(2)
button=driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/div[5]/div[2]/div/div[2]/div[2]/a[1]/div')
button.click()
#going back to your profile by finding your handele and clicking it

# %%
numbers=int(driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/ul/li[3]/a/span').text)
#finding the length of your following list
following_button=driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/header/section/ul/li[3]/a')
following_button.click()
# getting your following list and clicking it

# %%
lst_1=[]
count=0
while count < numbers:
        lst=driver.find_elements_by_class_name('FPmhX')
        for i in range(len(lst)):
            if count < numbers:
                lst_1.append(remove_html_tags(lst[i].get_attribute('innerHTML')))
                count+=1  
        # print(len(lst))
        
        scr1 = driver.find_element_by_class_name('isgrP')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scr1)

        time.sleep(4)
close=driver.find_element_by_xpath('/html/body/div[4]/div/div/div[1]/div/div[2]/button/div')
close.click()
# getting all the people who you fllow and appending their names in list 1

# %%
# comparing the list of follower of food talk and the people who you follow 
#(from the list of followers of foodtalk) and who dont follow u back
result= [element for element in lst_1 if element in lst_of_foodtalk]
#if you have just starting following followers ,pls refresh your profile page

result
# Out:
# ['_paramsharma._',
#  'kitchenkingkhan',
#  'aryanirfan94',
#  'simply_unique_1',
#  'momsbakezone']

# %% [markdown]
# Question 7:

# %%
search=driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
search.send_keys('codingninjas')
#searching coding ninjas

# %%
codingninjas=driver.find_element_by_class_name('z556c')
codingninjas.click()
#clicking on their handle

# %%
story=driver.find_element_by_class_name('RR-M-')
#finding class of story
if story.get_attribute('aria-disabled')=='true':
    #if story has not been put aria disabled atrribute will be true
    print('No story posted')
if story.get_attribute('aria-disabled')=='false':
    #if story has  been put aria disabled atrribute will be false
    k=driver.find_element_by_css_selector('#react-root > section > main > div > header > div > div > canvas')
    if k.get_attribute('height')=='114':
        story.click()
        print('you are now viewing')
    # if height of profile pic/ where story has been put the height will be 114 
    # if height is less then tory has been  already viewed
         
    else:
        print('story already viewed')
# Out:
# No story posted
